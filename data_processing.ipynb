# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr, spearmanr
from scipy.stats import linregress, t
pd.options.mode.chained_assignment = None
import seaborn as sns
import statsmodels.api as sm
import numpy as np

# %% [markdown]
# # Process data

# %% [markdown]
# ### Read raw data sets

# %%
national_data_1999_2023 = pd.read_csv("raw-data/national-data/1999-2023 National Data.csv")
state_data_1999_2023 = pd.read_csv("raw-data/state-data/1999-2023 State Data.csv")
county_data_1999_2023 = pd.read_csv("raw-data/county-data/1999-2023 County Data.csv")
agg_county_data_2018_2019 = pd.read_csv("raw-data/county-data/County Data 2018-2019/2018-2019 County Data.csv")
agg_county_data_2020_2021 = pd.read_csv("raw-data/county-data/County Data 2020-2021/2020-2021 County Data.csv")
agg_county_data_2022_2023 = pd.read_csv("raw-data/county-data/County Data 2022-2023/2022-2023 County Data.csv")
agg_ffl_data_2018_2019 = pd.read_csv("raw-data/0218-0219 Federal Firearms Listings.csv")
agg_ffl_data_2020_2021 = pd.read_csv("raw-data/0220-0221 Federal Firearms Listings.csv")
agg_ffl_data_2022_2023 = pd.read_csv("raw-data/0222-0223 Federal Firearms Listings.csv")
MSA_county_xwalk = pd.read_csv("raw-data/MSA-County Crosswalk 2013.csv")
state_fips = pd.read_csv("raw-data/State-FIPS Codes.csv")
dv_data = pd.read_csv("raw-data/Domestic Violence Programs.csv")
# Out:
# /var/folders/s7/nw_h3khx125gmbwtz4sztyj40000gn/T/ipykernel_42159/1540555240.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   county_data_1999_2023 = pd.read_csv("raw-data/county-data/1999-2023 County Data.csv")
# /var/folders/s7/nw_h3khx125gmbwtz4sztyj40000gn/T/ipykernel_42159/1540555240.py:7: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   agg_ffl_data_2018_2019 = pd.read_csv("raw-data/0218-0219 Federal Firearms Listings.csv")
# /var/folders/s7/nw_h3khx125gmbwtz4sztyj40000gn/T/ipykernel_42159/1540555240.py:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   agg_ffl_data_2020_2021 = pd.read_csv("raw-data/0220-0221 Federal Firearms Listings.csv")
# ...

# %% [markdown]
# ### Drop unnecessary columns

# %%
national_data_1999_2023.drop(national_data_1999_2023.columns[national_data_1999_2023.columns.str.contains('Non')], axis=1, inplace=True)
state_data_1999_2023.drop(state_data_1999_2023.columns[state_data_1999_2023.columns.str.contains('Non')], axis=1, inplace=True)
county_data_1999_2023.drop(county_data_1999_2023.columns[county_data_1999_2023.columns.str.contains('Non')], axis=1, inplace=True)
agg_county_data_2018_2019.drop(agg_county_data_2018_2019.columns[agg_county_data_2018_2019.columns.str.contains('Non')], axis=1, inplace=True)
agg_county_data_2020_2021.drop(agg_county_data_2020_2021.columns[agg_county_data_2020_2021.columns.str.contains('Non')], axis=1, inplace=True)
agg_county_data_2022_2023.drop(agg_county_data_2022_2023.columns[agg_county_data_2022_2023.columns.str.contains('Non')], axis=1, inplace=True)

# %% [markdown]
# ### Convert strings to numerics

# %%
national_data_1999_2023[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']] = national_data_1999_2023[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']].apply(pd.to_numeric, errors='coerce')

state_data_1999_2023[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']] = state_data_1999_2023[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']].apply(pd.to_numeric, errors='coerce')

county_data_1999_2023[['Population',#'Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths']] = county_data_1999_2023[['Population',#'Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths']].apply(pd.to_numeric, errors='coerce')

agg_county_data_2018_2019[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']] = agg_county_data_2018_2019[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']].apply(pd.to_numeric, errors='coerce')

agg_county_data_2020_2021[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']] = agg_county_data_2020_2021[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']].apply(pd.to_numeric, errors='coerce')

agg_county_data_2022_2023[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']] = agg_county_data_2022_2023[['Population','Female Population', 'Male Population', 
                       'Deaths', 'Female Deaths', 'Male Deaths', 'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths', 
                       'Homicides', 'Female Homicides', 'Male Homicides', 'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides', 
                       'Suicides', 'Female Suicides', 'Male Suicides', 'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides', 
                       'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths']].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ### Remove rows where population or deaths are zero

# %%
county_data_1999_2023 = county_data_1999_2023[county_data_1999_2023['Population'].notna()]
agg_county_data_2018_2019 = agg_county_data_2018_2019[agg_county_data_2018_2019['Population'].notna()]
agg_county_data_2020_2021 = agg_county_data_2020_2021[agg_county_data_2020_2021['Population'].notna()]
agg_county_data_2022_2023 = agg_county_data_2022_2023[agg_county_data_2022_2023['Population'].notna()]

county_data_1999_2023 = county_data_1999_2023[county_data_1999_2023['Deaths'].notna()].reset_index(drop=True)
agg_county_data_2018_2019 = agg_county_data_2018_2019[agg_county_data_2018_2019['Deaths'].notna()].reset_index(drop=True)
agg_county_data_2020_2021 = agg_county_data_2020_2021[agg_county_data_2020_2021['Deaths'].notna()].reset_index(drop=True)
agg_county_data_2022_2023 = agg_county_data_2022_2023[agg_county_data_2022_2023['Deaths'].notna()].reset_index(drop=True)

# %% [markdown]
# ### Clean dataset on licensed dealers

# %%
# rename state columns so they can be cross-referenced with other datasets
agg_ffl_data_2018_2019 = agg_ffl_data_2018_2019.rename(columns={'Premise State': 'State Code'})
agg_ffl_data_2020_2021 = agg_ffl_data_2020_2021.rename(columns={'Premise State': 'State Code'})
agg_ffl_data_2022_2023 = agg_ffl_data_2022_2023.rename(columns={'Premise State': 'State Code'})

# Remove rows where federal license type is not 06
agg_ffl_data_2018_2019 = agg_ffl_data_2018_2019[agg_ffl_data_2018_2019["Lic Type"] != 6].reset_index(drop=True)
agg_ffl_data_2020_2021 = agg_ffl_data_2020_2021[agg_ffl_data_2020_2021["Lic Type"] != 6].reset_index(drop=True)
agg_ffl_data_2022_2023 = agg_ffl_data_2022_2023[agg_ffl_data_2022_2023["Lic Type"] != 6].reset_index(drop=True)

# %% [markdown]
# ### Divide population size by the number of years

# %%
# agg_county_data_2018_2019[["Population","Female Population","Male Population"]] = agg_county_data_2018_2019[["Population","Female Population","Male Population"]]/2
# agg_county_data_2020_2021[["Population","Female Population","Male Population"]] = agg_county_data_2020_2021[["Population","Female Population","Male Population"]]/2
# agg_county_data_2022_2023[["Population","Female Population","Male Population"]] = agg_county_data_2022_2023[["Population","Female Population","Male Population"]]/2

# %% [markdown]
# ### Fill statistics for females where total population and male statistics are known

# %%
county_data_1999_2023.loc[county_data_1999_2023['Female Deaths'].isnull() & county_data_1999_2023['Male Deaths'].notnull(),"Female Deaths"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Female Deaths'].isnull() & county_data_1999_2023['Male Deaths'].notnull(),"Deaths"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Female Deaths'].isnull() & county_data_1999_2023['Male Deaths'].notnull(),"Male Deaths"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Deaths'].isnull() & agg_county_data_2018_2019['Male Deaths'].notnull(),"Female Deaths"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Deaths'].isnull() & agg_county_data_2018_2019['Male Deaths'].notnull(),"Deaths"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Deaths'].isnull() & agg_county_data_2018_2019['Male Deaths'].notnull(),"Male Deaths"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Deaths'].isnull() & agg_county_data_2020_2021['Male Deaths'].notnull(),"Female Deaths"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Deaths'].isnull() & agg_county_data_2020_2021['Male Deaths'].notnull(),"Deaths"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Deaths'].isnull() & agg_county_data_2020_2021['Male Deaths'].notnull(),"Male Deaths"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Deaths'].isnull() & agg_county_data_2022_2023['Male Deaths'].notnull(),"Female Deaths"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Deaths'].isnull() & agg_county_data_2022_2023['Male Deaths'].notnull(),"Deaths"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Deaths'].isnull() & agg_county_data_2022_2023['Male Deaths'].notnull(),"Male Deaths"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Deaths'].isnull() & county_data_1999_2023['Male Firearm Deaths'].notnull(),"Female Firearm Deaths"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Deaths'].isnull() & county_data_1999_2023['Male Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Deaths'].isnull() & county_data_1999_2023['Male Firearm Deaths'].notnull(),"Male Firearm Deaths"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Deaths'].isnull() & agg_county_data_2018_2019['Male Firearm Deaths'].notnull(),"Female Firearm Deaths"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Deaths'].isnull() & agg_county_data_2018_2019['Male Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Deaths'].isnull() & agg_county_data_2018_2019['Male Firearm Deaths'].notnull(),"Male Firearm Deaths"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Deaths'].isnull() & agg_county_data_2020_2021['Male Firearm Deaths'].notnull(),"Female Firearm Deaths"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Deaths'].isnull() & agg_county_data_2020_2021['Male Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Deaths'].isnull() & agg_county_data_2020_2021['Male Firearm Deaths'].notnull(),"Male Firearm Deaths"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Deaths'].isnull() & agg_county_data_2022_2023['Male Firearm Deaths'].notnull(),"Female Firearm Deaths"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Deaths'].isnull() & agg_county_data_2022_2023['Male Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Deaths'].isnull() & agg_county_data_2022_2023['Male Firearm Deaths'].notnull(),"Male Firearm Deaths"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Female Homicides'].isnull() & county_data_1999_2023['Male Homicides'].notnull(),"Female Homicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Female Homicides'].isnull() & county_data_1999_2023['Male Homicides'].notnull(),"Homicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Female Homicides'].isnull() & county_data_1999_2023['Male Homicides'].notnull(),"Male Homicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Homicides'].isnull() & agg_county_data_2018_2019['Male Homicides'].notnull(),"Female Homicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Homicides'].isnull() & agg_county_data_2018_2019['Male Homicides'].notnull(),"Homicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Homicides'].isnull() & agg_county_data_2018_2019['Male Homicides'].notnull(),"Male Homicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Homicides'].isnull() & agg_county_data_2020_2021['Male Homicides'].notnull(),"Female Homicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Homicides'].isnull() & agg_county_data_2020_2021['Male Homicides'].notnull(),"Homicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Homicides'].isnull() & agg_county_data_2020_2021['Male Homicides'].notnull(),"Male Homicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Homicides'].isnull() & agg_county_data_2022_2023['Male Homicides'].notnull(),"Female Homicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Homicides'].isnull() & agg_county_data_2022_2023['Male Homicides'].notnull(),"Homicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Homicides'].isnull() & agg_county_data_2022_2023['Male Homicides'].notnull(),"Male Homicides"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Homicides'].isnull() & county_data_1999_2023['Male Firearm Homicides'].notnull(),"Female Firearm Homicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Homicides'].isnull() & county_data_1999_2023['Male Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Homicides'].isnull() & county_data_1999_2023['Male Firearm Homicides'].notnull(),"Male Firearm Homicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Homicides'].isnull() & agg_county_data_2018_2019['Male Firearm Homicides'].notnull(),"Female Firearm Homicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Homicides'].isnull() & agg_county_data_2018_2019['Male Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Homicides'].isnull() & agg_county_data_2018_2019['Male Firearm Homicides'].notnull(),"Male Firearm Homicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Homicides'].isnull() & agg_county_data_2020_2021['Male Firearm Homicides'].notnull(),"Female Firearm Homicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Homicides'].isnull() & agg_county_data_2020_2021['Male Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Homicides'].isnull() & agg_county_data_2020_2021['Male Firearm Homicides'].notnull(),"Male Firearm Homicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Homicides'].isnull() & agg_county_data_2022_2023['Male Firearm Homicides'].notnull(),"Female Firearm Homicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Homicides'].isnull() & agg_county_data_2022_2023['Male Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Homicides'].isnull() & agg_county_data_2022_2023['Male Firearm Homicides'].notnull(),"Male Firearm Homicides"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Female Suicides'].isnull() & county_data_1999_2023['Male Suicides'].notnull(),"Female Suicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Female Suicides'].isnull() & county_data_1999_2023['Male Suicides'].notnull(),"Suicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Female Suicides'].isnull() & county_data_1999_2023['Male Suicides'].notnull(),"Male Suicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Suicides'].isnull() & agg_county_data_2018_2019['Male Suicides'].notnull(),"Female Suicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Suicides'].isnull() & agg_county_data_2018_2019['Male Suicides'].notnull(),"Suicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Suicides'].isnull() & agg_county_data_2018_2019['Male Suicides'].notnull(),"Male Suicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Suicides'].isnull() & agg_county_data_2020_2021['Male Suicides'].notnull(),"Female Suicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Suicides'].isnull() & agg_county_data_2020_2021['Male Suicides'].notnull(),"Suicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Suicides'].isnull() & agg_county_data_2020_2021['Male Suicides'].notnull(),"Male Suicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Suicides'].isnull() & agg_county_data_2022_2023['Male Suicides'].notnull(),"Female Suicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Suicides'].isnull() & agg_county_data_2022_2023['Male Suicides'].notnull(),"Suicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Suicides'].isnull() & agg_county_data_2022_2023['Male Suicides'].notnull(),"Male Suicides"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Suicides'].isnull() & county_data_1999_2023['Male Firearm Suicides'].notnull(),"Female Firearm Suicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Suicides'].isnull() & county_data_1999_2023['Male Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Female Firearm Suicides'].isnull() & county_data_1999_2023['Male Firearm Suicides'].notnull(),"Male Firearm Suicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Suicides'].isnull() & agg_county_data_2018_2019['Male Firearm Suicides'].notnull(),"Female Firearm Suicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Suicides'].isnull() & agg_county_data_2018_2019['Male Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female Firearm Suicides'].isnull() & agg_county_data_2018_2019['Male Firearm Suicides'].notnull(),"Male Firearm Suicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Suicides'].isnull() & agg_county_data_2020_2021['Male Firearm Suicides'].notnull(),"Female Firearm Suicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Suicides'].isnull() & agg_county_data_2020_2021['Male Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female Firearm Suicides'].isnull() & agg_county_data_2020_2021['Male Firearm Suicides'].notnull(),"Male Firearm Suicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Suicides'].isnull() & agg_county_data_2022_2023['Male Firearm Suicides'].notnull(),"Female Firearm Suicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Suicides'].isnull() & agg_county_data_2022_2023['Male Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female Firearm Suicides'].isnull() & agg_county_data_2022_2023['Male Firearm Suicides'].notnull(),"Male Firearm Suicides"].to_list())]

agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female COVID Deaths'].isnull() & agg_county_data_2018_2019['Male COVID Deaths'].notnull(),"Female COVID Deaths"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female COVID Deaths'].isnull() & agg_county_data_2018_2019['Male COVID Deaths'].notnull(),"COVID Deaths"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Female COVID Deaths'].isnull() & agg_county_data_2018_2019['Male COVID Deaths'].notnull(),"Male COVID Deaths"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female COVID Deaths'].isnull() & agg_county_data_2020_2021['Male COVID Deaths'].notnull(),"Female COVID Deaths"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female COVID Deaths'].isnull() & agg_county_data_2020_2021['Male COVID Deaths'].notnull(),"COVID Deaths"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Female COVID Deaths'].isnull() & agg_county_data_2020_2021['Male COVID Deaths'].notnull(),"Male COVID Deaths"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female COVID Deaths'].isnull() & agg_county_data_2022_2023['Male COVID Deaths'].notnull(),"Female COVID Deaths"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female COVID Deaths'].isnull() & agg_county_data_2022_2023['Male COVID Deaths'].notnull(),"COVID Deaths"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Female COVID Deaths'].isnull() & agg_county_data_2022_2023['Male COVID Deaths'].notnull(),"Male COVID Deaths"].to_list())]

# %% [markdown]
# ### Fill statistics for males where total population and female statistics are known

# %%
county_data_1999_2023.loc[county_data_1999_2023['Male Deaths'].isnull() & county_data_1999_2023['Female Deaths'].notnull(),"Male Deaths"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Male Deaths'].isnull() & county_data_1999_2023['Female Deaths'].notnull(),"Deaths"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Male Deaths'].isnull() & county_data_1999_2023['Female Deaths'].notnull(),"Female Deaths"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Deaths'].isnull() & agg_county_data_2018_2019['Female Deaths'].notnull(),"Male Deaths"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Deaths'].isnull() & agg_county_data_2018_2019['Female Deaths'].notnull(),"Deaths"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Deaths'].isnull() & agg_county_data_2018_2019['Female Deaths'].notnull(),"Female Deaths"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Deaths'].isnull() & agg_county_data_2020_2021['Female Deaths'].notnull(),"Male Deaths"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Deaths'].isnull() & agg_county_data_2020_2021['Female Deaths'].notnull(),"Deaths"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Deaths'].isnull() & agg_county_data_2020_2021['Female Deaths'].notnull(),"Female Deaths"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Deaths'].isnull() & agg_county_data_2022_2023['Female Deaths'].notnull(),"Male Deaths"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Deaths'].isnull() & agg_county_data_2022_2023['Female Deaths'].notnull(),"Deaths"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Deaths'].isnull() & agg_county_data_2022_2023['Female Deaths'].notnull(),"Female Deaths"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Deaths'].isnull() & county_data_1999_2023['Female Firearm Deaths'].notnull(),"Male Firearm Deaths"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Deaths'].isnull() & county_data_1999_2023['Female Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Deaths'].isnull() & county_data_1999_2023['Female Firearm Deaths'].notnull(),"Female Firearm Deaths"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Deaths'].isnull() & agg_county_data_2018_2019['Female Firearm Deaths'].notnull(),"Male Firearm Deaths"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Deaths'].isnull() & agg_county_data_2018_2019['Female Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Deaths'].isnull() & agg_county_data_2018_2019['Female Firearm Deaths'].notnull(),"Female Firearm Deaths"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Deaths'].isnull() & agg_county_data_2020_2021['Female Firearm Deaths'].notnull(),"Male Firearm Deaths"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Deaths'].isnull() & agg_county_data_2020_2021['Female Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Deaths'].isnull() & agg_county_data_2020_2021['Female Firearm Deaths'].notnull(),"Female Firearm Deaths"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Deaths'].isnull() & agg_county_data_2022_2023['Female Firearm Deaths'].notnull(),"Male Firearm Deaths"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Deaths'].isnull() & agg_county_data_2022_2023['Female Firearm Deaths'].notnull(),"Firearm Deaths"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Deaths'].isnull() & agg_county_data_2022_2023['Female Firearm Deaths'].notnull(),"Female Firearm Deaths"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Male Homicides'].isnull() & county_data_1999_2023['Female Homicides'].notnull(),"Male Homicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Male Homicides'].isnull() & county_data_1999_2023['Female Homicides'].notnull(),"Homicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Male Homicides'].isnull() & county_data_1999_2023['Female Homicides'].notnull(),"Female Homicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Homicides'].isnull() & agg_county_data_2018_2019['Female Homicides'].notnull(),"Male Homicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Homicides'].isnull() & agg_county_data_2018_2019['Female Homicides'].notnull(),"Homicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Homicides'].isnull() & agg_county_data_2018_2019['Female Homicides'].notnull(),"Female Homicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Homicides'].isnull() & agg_county_data_2020_2021['Female Homicides'].notnull(),"Male Homicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Homicides'].isnull() & agg_county_data_2020_2021['Female Homicides'].notnull(),"Homicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Homicides'].isnull() & agg_county_data_2020_2021['Female Homicides'].notnull(),"Female Homicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Homicides'].isnull() & agg_county_data_2022_2023['Female Homicides'].notnull(),"Male Homicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Homicides'].isnull() & agg_county_data_2022_2023['Female Homicides'].notnull(),"Homicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Homicides'].isnull() & agg_county_data_2022_2023['Female Homicides'].notnull(),"Female Homicides"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Homicides'].isnull() & county_data_1999_2023['Female Firearm Homicides'].notnull(),"Male Firearm Homicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Homicides'].isnull() & county_data_1999_2023['Female Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Homicides'].isnull() & county_data_1999_2023['Female Firearm Homicides'].notnull(),"Female Firearm Homicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Homicides'].isnull() & agg_county_data_2018_2019['Female Firearm Homicides'].notnull(),"Male Firearm Homicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Homicides'].isnull() & agg_county_data_2018_2019['Female Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Homicides'].isnull() & agg_county_data_2018_2019['Female Firearm Homicides'].notnull(),"Female Firearm Homicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Homicides'].isnull() & agg_county_data_2020_2021['Female Firearm Homicides'].notnull(),"Male Firearm Homicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Homicides'].isnull() & agg_county_data_2020_2021['Female Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Homicides'].isnull() & agg_county_data_2020_2021['Female Firearm Homicides'].notnull(),"Female Firearm Homicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Homicides'].isnull() & agg_county_data_2022_2023['Female Firearm Homicides'].notnull(),"Male Firearm Homicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Homicides'].isnull() & agg_county_data_2022_2023['Female Firearm Homicides'].notnull(),"Firearm Homicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Homicides'].isnull() & agg_county_data_2022_2023['Female Firearm Homicides'].notnull(),"Female Firearm Homicides"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Male Suicides'].isnull() & county_data_1999_2023['Female Suicides'].notnull(),"Male Suicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Male Suicides'].isnull() & county_data_1999_2023['Female Suicides'].notnull(),"Suicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Male Suicides'].isnull() & county_data_1999_2023['Female Suicides'].notnull(),"Female Suicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Suicides'].isnull() & agg_county_data_2018_2019['Female Suicides'].notnull(),"Male Suicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Suicides'].isnull() & agg_county_data_2018_2019['Female Suicides'].notnull(),"Suicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Suicides'].isnull() & agg_county_data_2018_2019['Female Suicides'].notnull(),"Female Suicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Suicides'].isnull() & agg_county_data_2020_2021['Female Suicides'].notnull(),"Male Suicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Suicides'].isnull() & agg_county_data_2020_2021['Female Suicides'].notnull(),"Suicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Suicides'].isnull() & agg_county_data_2020_2021['Female Suicides'].notnull(),"Female Suicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Suicides'].isnull() & agg_county_data_2022_2023['Female Suicides'].notnull(),"Male Suicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Suicides'].isnull() & agg_county_data_2022_2023['Female Suicides'].notnull(),"Suicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Suicides'].isnull() & agg_county_data_2022_2023['Female Suicides'].notnull(),"Female Suicides"].to_list())]

county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Suicides'].isnull() & county_data_1999_2023['Female Firearm Suicides'].notnull(),"Male Firearm Suicides"] = [x - y for x, y in zip(county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Suicides'].isnull() & county_data_1999_2023['Female Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), county_data_1999_2023.loc[county_data_1999_2023['Male Firearm Suicides'].isnull() & county_data_1999_2023['Female Firearm Suicides'].notnull(),"Female Firearm Suicides"].to_list())]
agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Suicides'].isnull() & agg_county_data_2018_2019['Female Firearm Suicides'].notnull(),"Male Firearm Suicides"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Suicides'].isnull() & agg_county_data_2018_2019['Female Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Firearm Suicides'].isnull() & agg_county_data_2018_2019['Female Firearm Suicides'].notnull(),"Female Firearm Suicides"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Suicides'].isnull() & agg_county_data_2020_2021['Female Firearm Suicides'].notnull(),"Male Firearm Suicides"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Suicides'].isnull() & agg_county_data_2020_2021['Female Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Firearm Suicides'].isnull() & agg_county_data_2020_2021['Female Firearm Suicides'].notnull(),"Female Firearm Suicides"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Suicides'].isnull() & agg_county_data_2022_2023['Female Firearm Suicides'].notnull(),"Male Firearm Suicides"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Suicides'].isnull() & agg_county_data_2022_2023['Female Firearm Suicides'].notnull(),"Firearm Suicides"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Firearm Suicides'].isnull() & agg_county_data_2022_2023['Female Firearm Suicides'].notnull(),"Female Firearm Suicides"].to_list())]

agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male COVID Deaths'].isnull() & agg_county_data_2018_2019['Female COVID Deaths'].notnull(),"Male COVID Deaths"] = [x - y for x, y in zip(agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male COVID Deaths'].isnull() & agg_county_data_2018_2019['Female COVID Deaths'].notnull(),"COVID Deaths"].to_list(), agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male COVID Deaths'].isnull() & agg_county_data_2018_2019['Female COVID Deaths'].notnull(),"Female COVID Deaths"].to_list())]
agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male COVID Deaths'].isnull() & agg_county_data_2020_2021['Female COVID Deaths'].notnull(),"Male COVID Deaths"] = [x - y for x, y in zip(agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male COVID Deaths'].isnull() & agg_county_data_2020_2021['Female COVID Deaths'].notnull(),"COVID Deaths"].to_list(), agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male COVID Deaths'].isnull() & agg_county_data_2020_2021['Female COVID Deaths'].notnull(),"Female COVID Deaths"].to_list())]
agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male COVID Deaths'].isnull() & agg_county_data_2022_2023['Female COVID Deaths'].notnull(),"Male COVID Deaths"] = [x - y for x, y in zip(agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male COVID Deaths'].isnull() & agg_county_data_2022_2023['Female COVID Deaths'].notnull(),"COVID Deaths"].to_list(), agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male COVID Deaths'].isnull() & agg_county_data_2022_2023['Female COVID Deaths'].notnull(),"Female COVID Deaths"].to_list())]

# %% [markdown]
# ### Remove rows where both female deaths and male deaths are unknown

# %%
agg_county_data_2018_2019 = agg_county_data_2018_2019.loc[agg_county_data_2018_2019['Male Deaths'].notnull() & agg_county_data_2018_2019['Female Deaths'].notnull()]
agg_county_data_2020_2021 = agg_county_data_2020_2021.loc[agg_county_data_2020_2021['Male Deaths'].notnull() & agg_county_data_2020_2021['Female Deaths'].notnull()]
agg_county_data_2022_2023 = agg_county_data_2022_2023.loc[agg_county_data_2022_2023['Male Deaths'].notnull() & agg_county_data_2022_2023['Female Deaths'].notnull()]

# %% [markdown]
# ### Add number of licensed dealers

# %%
agg_ffl_data_2018_2019 = pd.read_csv("raw-data/0218-0219 Federal Firearms Listings.csv")
agg_ffl_data_2020_2021 = pd.read_csv("raw-data/0220-0221 Federal Firearms Listings.csv")
agg_ffl_data_2022_2023 = pd.read_csv("raw-data/0222-0223 Federal Firearms Listings.csv")

# rename state columns so they can be cross-referenced with other datasets
agg_ffl_data_2018_2019 = agg_ffl_data_2018_2019.rename(columns={'Premise State': 'State Code'})
agg_ffl_data_2020_2021 = agg_ffl_data_2020_2021.rename(columns={'Premise State': 'State Code'})
agg_ffl_data_2022_2023 = agg_ffl_data_2022_2023.rename(columns={'Premise State': 'State Code'})

# Remove rows where federal license type is not 06
agg_ffl_data_2018_2019 = agg_ffl_data_2018_2019[agg_ffl_data_2018_2019["Lic Type"] != 6].reset_index(drop=True)
agg_ffl_data_2020_2021 = agg_ffl_data_2020_2021[agg_ffl_data_2020_2021["Lic Type"] != 6].reset_index(drop=True)
agg_ffl_data_2022_2023 = agg_ffl_data_2022_2023[agg_ffl_data_2022_2023["Lic Type"] != 6].reset_index(drop=True)

# merge each entry's FIPS code
agg_ffl_data_2018_2019 = pd.merge(agg_ffl_data_2018_2019, state_fips[['State Code', 'FIPS Code']], on='State Code', how='left')
agg_ffl_data_2020_2021 = pd.merge(agg_ffl_data_2020_2021, state_fips[['State Code', 'FIPS Code']], on='State Code', how='left')
agg_ffl_data_2022_2023 = pd.merge(agg_ffl_data_2022_2023, state_fips[['State Code', 'FIPS Code']], on='State Code', how='left')

# remove lines with N/A FIPS code (e.g., Puerto Rico)
agg_ffl_data_2018_2019 = agg_ffl_data_2018_2019[agg_ffl_data_2018_2019['FIPS Code'].notna()].reset_index(drop=True)
agg_ffl_data_2020_2021 = agg_ffl_data_2020_2021[agg_ffl_data_2020_2021['FIPS Code'].notna()].reset_index(drop=True)
agg_ffl_data_2022_2023 = agg_ffl_data_2022_2023[agg_ffl_data_2022_2023['FIPS Code'].notna()].reset_index(drop=True)

# convert FIPS code to string
agg_ffl_data_2018_2019['FIPS Code'] = agg_ffl_data_2018_2019['FIPS Code'].astype(int).astype(str)
agg_ffl_data_2020_2021['FIPS Code'] = agg_ffl_data_2020_2021['FIPS Code'].astype(int).astype(str)
agg_ffl_data_2022_2023['FIPS Code'] = agg_ffl_data_2022_2023['FIPS Code'].astype(int).astype(str)

# convert county number to string and add 0 to if it has only two numbers so it can be appended to the fips code correctly
agg_ffl_data_2018_2019['Lic Cnty'] = agg_ffl_data_2018_2019['Lic Cnty'].astype(str).apply(lambda x: '00' + x if len(x) == 1 else x) 
agg_ffl_data_2020_2021['Lic Cnty'] = agg_ffl_data_2020_2021['Lic Cnty'].astype(str).apply(lambda x: '00' + x if len(x) == 1 else x)
agg_ffl_data_2022_2023['Lic Cnty'] = agg_ffl_data_2022_2023['Lic Cnty'].astype(str).apply(lambda x: '00' + x if len(x) == 1 else x)
agg_ffl_data_2018_2019['Lic Cnty'] = agg_ffl_data_2018_2019['Lic Cnty'].astype(str).apply(lambda x: '0' + x if len(x) == 2 else x) 
agg_ffl_data_2020_2021['Lic Cnty'] = agg_ffl_data_2020_2021['Lic Cnty'].astype(str).apply(lambda x: '0' + x if len(x) == 2 else x)
agg_ffl_data_2022_2023['Lic Cnty'] = agg_ffl_data_2022_2023['Lic Cnty'].astype(str).apply(lambda x: '0' + x if len(x) == 2 else x)

# append county code to fips code to get a state-county code that can be cross-referenced with MSA crosswalk
agg_ffl_data_2018_2019['County Code'] = agg_ffl_data_2018_2019['FIPS Code'].astype(str)+agg_ffl_data_2018_2019['Lic Cnty']
agg_ffl_data_2020_2021['County Code'] = agg_ffl_data_2020_2021['FIPS Code'].astype(str)+agg_ffl_data_2020_2021['Lic Cnty']
agg_ffl_data_2022_2023['County Code'] = agg_ffl_data_2022_2023['FIPS Code'].astype(str)+agg_ffl_data_2022_2023['Lic Cnty']

# count the number of ffls in each county
agg_county_ffl_data_2018_2019 = agg_ffl_data_2018_2019['County Code'].value_counts().to_frame().reset_index().rename(columns={'index':'values', 'values':'count'})
agg_county_ffl_data_2020_2021 = agg_ffl_data_2020_2021['County Code'].value_counts().to_frame().reset_index().rename(columns={'index':'values', 'values':'count'})
agg_county_ffl_data_2022_2023 = agg_ffl_data_2022_2023['County Code'].value_counts().to_frame().reset_index().rename(columns={'index':'values', 'values':'count'})

# rename columns
agg_county_ffl_data_2018_2019 = agg_county_ffl_data_2018_2019.rename(columns={'count': 'Licensed Dealerships'})
agg_county_ffl_data_2020_2021 = agg_county_ffl_data_2020_2021.rename(columns={'count': 'Licensed Dealerships'})
agg_county_ffl_data_2022_2023 = agg_county_ffl_data_2022_2023.rename(columns={'count': 'Licensed Dealerships'})

# change the type of county code to integer so it can be merged with other dataframes
agg_county_ffl_data_2018_2019['County Code'] = agg_county_ffl_data_2018_2019['County Code'].astype(int)
agg_county_ffl_data_2020_2021['County Code'] = agg_county_ffl_data_2020_2021['County Code'].astype(int)
agg_county_ffl_data_2022_2023['County Code'] = agg_county_ffl_data_2022_2023['County Code'].astype(int)

# merge each county's number of licensed dealerships
agg_county_data_2018_2019 = pd.merge(agg_county_data_2018_2019, agg_county_ffl_data_2018_2019[['County Code', 'Licensed Dealerships']], on='County Code', how='left')
agg_county_data_2020_2021 = pd.merge(agg_county_data_2020_2021, agg_county_ffl_data_2020_2021[['County Code', 'Licensed Dealerships']], on='County Code', how='left')
agg_county_data_2022_2023 = pd.merge(agg_county_data_2022_2023, agg_county_ffl_data_2022_2023[['County Code', 'Licensed Dealerships']], on='County Code', how='left')
# Out:
# /var/folders/s7/nw_h3khx125gmbwtz4sztyj40000gn/T/ipykernel_42159/555344532.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   agg_ffl_data_2018_2019 = pd.read_csv("raw-data/0218-0219 Federal Firearms Listings.csv")
# /var/folders/s7/nw_h3khx125gmbwtz4sztyj40000gn/T/ipykernel_42159/555344532.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   agg_ffl_data_2020_2021 = pd.read_csv("raw-data/0220-0221 Federal Firearms Listings.csv")
# /var/folders/s7/nw_h3khx125gmbwtz4sztyj40000gn/T/ipykernel_42159/555344532.py:3: DtypeWarning: Columns (11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   agg_ffl_data_2022_2023 = pd.read_csv("raw-data/0222-0223 Federal Firearms Listings.csv")

# %% [markdown]
# ### Add number of Domestic Violence Shelters

# %%
# add column of zeroes for Domestic Violence Shelters
agg_county_data_2018_2019['Domestic Violence Shelters'] = 0
agg_county_data_2020_2021['Domestic Violence Shelters'] = 0
agg_county_data_2022_2023['Domestic Violence Shelters'] = 0

for c in range(len(agg_county_data_2018_2019)):
    county_code = agg_county_data_2018_2019["County Code"][c]
    agg_county_data_2018_2019.loc[c,"Domestic Violence Shelters"] = np.sum(dv_data[dv_data["County Code"] == county_code]["Domestic Violence Shelters"])

for c in range(len(agg_county_data_2020_2021)):
    county_code = agg_county_data_2020_2021["County Code"][c]
    agg_county_data_2020_2021.loc[c,"Domestic Violence Shelters"] = np.sum(dv_data[dv_data["County Code"] == county_code]["Domestic Violence Shelters"])

for c in range(len(agg_county_data_2022_2023)):
    county_code = agg_county_data_2022_2023["County Code"][c]
    agg_county_data_2022_2023.loc[c,"Domestic Violence Shelters"] = np.sum(dv_data[dv_data["County Code"] == county_code]["Domestic Violence Shelters"])

# %% [markdown]
# ### Save processed data

# %%
national_data_1999_2023.to_csv("processed-data/1999-2023 Nation Data.csv", index=False)
state_data_1999_2023.to_csv("processed-data/1999-2023 State Data.csv", index=False)
county_data_1999_2023.to_csv("processed-data/1999-2023 County Data.csv", index=False)
agg_county_data_2018_2019.to_csv("processed-data/2018-2019 Aggregate County Data.csv", index=False)
agg_county_data_2020_2021.to_csv("processed-data/2020-2021 Aggregate County Data.csv", index=False)
agg_county_data_2022_2023.to_csv("processed-data/2022-2023 Aggregate County Data.csv", index=False)

# %% [markdown]
# ### Merge counties into MSAs

# %%
# create a data frame for MSA data
n_MSAs = len(MSA_county_xwalk["MSA Code"].drop_duplicates())
MSA_data = pd.DataFrame({'MSA Code' : MSA_county_xwalk["MSA Code"].drop_duplicates(), 'MSA Title' : MSA_county_xwalk["MSA Title"].drop_duplicates()})

# add columns names
MSA_data[['State', 'State Code', 
          'Population', 'Female Population', 'Male Population',
          'Deaths', 'Female Deaths', 'Male Deaths',
          'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths',
          'Homicides', 'Female Homicides', 'Male Homicides',
          'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides',
          'Suicides', 'Female Suicides', 'Male Suicides', 
          'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides',
          'COVID Deaths', 'Female COVID Deaths', 'Male COVID Deaths',
          'Licensed Dealerships','Domestic Violence Shelters']] = np.nan

# remove rows that contain Puerto Rico
MSA_data = MSA_data[MSA_data["MSA Title"].str.contains(", PR") == False].reset_index(drop=True)

# convert the state column to string-type
MSA_data['State'] = MSA_data.State.astype(str)

# make copies of the dataframe for each time frame
agg_MSA_data_2018_2019 = MSA_data.copy()
agg_MSA_data_2020_2021 = MSA_data.copy()
agg_MSA_data_2022_2023 = MSA_data.copy()

# remove licensed dealerships column for dataframes that do not contain it
agg_MSA_data_2018_2019 = agg_MSA_data_2018_2019.drop('Licensed Dealerships', axis=1)
agg_MSA_data_2020_2021 = agg_MSA_data_2020_2021.drop('Licensed Dealerships', axis=1)
agg_MSA_data_2022_2023 = agg_MSA_data_2022_2023.drop('Licensed Dealerships', axis=1)

# for each MSA, aggregate counts from county data
for c in range(len(MSA_data)):
    MSA_code = MSA_data["MSA Code"].iloc[c]
    county_codes = MSA_county_xwalk[MSA_county_xwalk["MSA Code"]==MSA_code]["County Code"]
    # aggregate for 2018-2019
    if not agg_county_data_2018_2019.loc[(agg_county_data_2018_2019["County Code"].isin(county_codes))].empty: # if there are counties withi the MSA
        counties = agg_county_data_2018_2019.loc[(agg_county_data_2018_2019["County Code"].isin(county_codes))] # subset the counties in the MSA
        agg_MSA_data_2018_2019.loc[c,"State"] = counties["State"].reset_index(drop=True)[0]
        agg_MSA_data_2018_2019.loc[c,"State Code"] = counties["State Code"].reset_index(drop=True)[0]
        agg_MSA_data_2018_2019.loc[c,"Population"] = np.sum(counties["Population"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Population"] = np.sum(counties["Female Population"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Population"] = np.sum(counties["Male Population"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Deaths"] = np.sum(counties["Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Deaths"] = np.sum(counties["Female Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Deaths"] = np.sum(counties["Male Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Firearm Deaths"] = np.sum(counties["Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Firearm Deaths"] = np.sum(counties["Female Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Firearm Deaths"] = np.sum(counties["Male Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Homicides"] = np.sum(counties["Homicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Homicides"] = np.sum(counties["Male Homicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Homicides"] = np.sum(counties["Female Homicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Firearm Homicides"] = np.sum(counties["Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Firearm Homicides"] = np.sum(counties["Male Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Firearm Homicides"] = np.sum(counties["Female Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Suicides"] = np.sum(counties["Suicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Suicides"] = np.sum(counties["Male Suicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Suicides"] = np.sum(counties["Female Suicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Firearm Suicides"] = np.sum(counties["Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male Firearm Suicides"] = np.sum(counties["Male Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female Firearm Suicides"] = np.sum(counties["Female Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"COVID Deaths"] = np.sum(counties["COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Male COVID Deaths"] = np.sum(counties["Male COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Female COVID Deaths"] = np.sum(counties["Female COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Licensed Dealerships"] = np.sum(counties["Licensed Dealerships"].dropna().astype(int))
        agg_MSA_data_2018_2019.loc[c,"Domestic Violence Shelters"] = np.sum(counties["Domestic Violence Shelters"].dropna().astype(int))
    # aggregate for 2020-2021
    if not agg_county_data_2020_2021.loc[(agg_county_data_2020_2021["County Code"].isin(county_codes))].empty: # if there are counties withi the MSA
        counties = agg_county_data_2020_2021.loc[(agg_county_data_2020_2021["County Code"].isin(county_codes))] # subset the counties in the MSA
        agg_MSA_data_2020_2021.loc[c,"State"] = counties["State"].reset_index(drop=True)[0]
        agg_MSA_data_2020_2021.loc[c,"State Code"] = counties["State Code"].reset_index(drop=True)[0]
        agg_MSA_data_2020_2021.loc[c,"Population"] = np.sum(counties["Population"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Population"] = np.sum(counties["Female Population"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Population"] = np.sum(counties["Male Population"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Deaths"] = np.sum(counties["Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Deaths"] = np.sum(counties["Female Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Deaths"] = np.sum(counties["Male Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Firearm Deaths"] = np.sum(counties["Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Firearm Deaths"] = np.sum(counties["Female Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Firearm Deaths"] = np.sum(counties["Male Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Homicides"] = np.sum(counties["Homicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Homicides"] = np.sum(counties["Male Homicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Homicides"] = np.sum(counties["Female Homicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Firearm Homicides"] = np.sum(counties["Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Firearm Homicides"] = np.sum(counties["Male Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Firearm Homicides"] = np.sum(counties["Female Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Suicides"] = np.sum(counties["Suicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Suicides"] = np.sum(counties["Male Suicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Suicides"] = np.sum(counties["Female Suicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Firearm Suicides"] = np.sum(counties["Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male Firearm Suicides"] = np.sum(counties["Male Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female Firearm Suicides"] = np.sum(counties["Female Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"COVID Deaths"] = np.sum(counties["COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Male COVID Deaths"] = np.sum(counties["Male COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Female COVID Deaths"] = np.sum(counties["Female COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Licensed Dealerships"] = np.sum(counties["Licensed Dealerships"].dropna().astype(int))
        agg_MSA_data_2020_2021.loc[c,"Domestic Violence Shelters"] = np.sum(counties["Domestic Violence Shelters"].dropna().astype(int))
    # aggregate for 2022-2023
    if not agg_county_data_2022_2023.loc[(agg_county_data_2022_2023["County Code"].isin(county_codes))].empty: # if there are counties withi the MSA
        counties = agg_county_data_2022_2023.loc[(agg_county_data_2022_2023["County Code"].isin(county_codes))] # subset the counties in the MSA
        agg_MSA_data_2022_2023.loc[c,"State"] = counties["State"].reset_index(drop=True)[0]
        agg_MSA_data_2022_2023.loc[c,"State Code"] = counties["State Code"].reset_index(drop=True)[0]
        agg_MSA_data_2022_2023.loc[c,"Population"] = np.sum(counties["Population"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Population"] = np.sum(counties["Female Population"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Population"] = np.sum(counties["Male Population"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Deaths"] = np.sum(counties["Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Deaths"] = np.sum(counties["Female Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Deaths"] = np.sum(counties["Male Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Firearm Deaths"] = np.sum(counties["Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Firearm Deaths"] = np.sum(counties["Female Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Firearm Deaths"] = np.sum(counties["Male Firearm Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Homicides"] = np.sum(counties["Homicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Homicides"] = np.sum(counties["Male Homicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Homicides"] = np.sum(counties["Female Homicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Firearm Homicides"] = np.sum(counties["Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Firearm Homicides"] = np.sum(counties["Male Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Firearm Homicides"] = np.sum(counties["Female Firearm Homicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Suicides"] = np.sum(counties["Suicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Suicides"] = np.sum(counties["Male Suicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Suicides"] = np.sum(counties["Female Suicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Firearm Suicides"] = np.sum(counties["Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male Firearm Suicides"] = np.sum(counties["Male Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female Firearm Suicides"] = np.sum(counties["Female Firearm Suicides"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"COVID Deaths"] = np.sum(counties["COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Male COVID Deaths"] = np.sum(counties["Male COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Female COVID Deaths"] = np.sum(counties["Female COVID Deaths"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Licensed Dealerships"] = np.sum(counties["Licensed Dealerships"].dropna().astype(int))
        agg_MSA_data_2022_2023.loc[c,"Domestic Violence Shelters"] = np.sum(counties["Domestic Violence Shelters"].dropna().astype(int))


# remove rows where MSA contains population 0 or N/A
agg_MSA_data_2018_2019 = agg_MSA_data_2018_2019[agg_MSA_data_2018_2019["Population"] != 0]
agg_MSA_data_2018_2019 = agg_MSA_data_2018_2019[agg_MSA_data_2018_2019['Population'].notna()]
agg_MSA_data_2020_2021 = agg_MSA_data_2020_2021[agg_MSA_data_2020_2021["Population"] != 0]
agg_MSA_data_2020_2021 = agg_MSA_data_2020_2021[agg_MSA_data_2020_2021['Population'].notna()]
agg_MSA_data_2022_2023 = agg_MSA_data_2022_2023[agg_MSA_data_2022_2023["Population"] != 0]
agg_MSA_data_2022_2023 = agg_MSA_data_2022_2023[agg_MSA_data_2022_2023['Population'].notna()]

# save MSA data
agg_MSA_data_2018_2019.to_csv("processed-data/2018-2019 Aggregated MSA data.csv", index=False)
agg_MSA_data_2020_2021.to_csv("processed-data/2020-2021 Aggregated MSA data.csv", index=False)
agg_MSA_data_2022_2023.to_csv("processed-data/2022-2023 Aggregated MSA data.csv", index=False)

# %%
# create a data frame for MSA data
MSA_data_1999_2023 = pd.concat([county_data_1999_2023[["Year"]].drop_duplicates().assign(MSA=c) for c in MSA_data["MSA Code"]], ignore_index=True)
MSA_data_1999_2023["MSA Title"] = pd.concat([county_data_1999_2023[["Year"]].drop_duplicates().assign(Title=t) for t in MSA_data["MSA Title"]], ignore_index=True)["Title"]
MSA_data_1999_2023 = MSA_data_1999_2023.rename(columns={"MSA": "MSA Code"})

# add columns names
MSA_data_1999_2023[['State', 'State Code', 
          'Population', #'Female Population', 'Male Population',
          'Deaths', 'Female Deaths', 'Male Deaths',
          'Firearm Deaths', 'Female Firearm Deaths', 'Male Firearm Deaths',
          'Homicides', 'Female Homicides', 'Male Homicides',
          'Firearm Homicides', 'Female Firearm Homicides', 'Male Firearm Homicides',
          'Suicides', 'Female Suicides', 'Male Suicides', 
          'Firearm Suicides', 'Female Firearm Suicides', 'Male Firearm Suicides',
          'COVID Deaths']] = np.nan

# convert the state column to string-type
MSA_data_1999_2023['State'] = MSA_data_1999_2023.State.astype(str)

# for each MSA, aggregate counts from county data
MSA_codes = MSA_data_1999_2023["MSA Code"].drop_duplicates()
years = MSA_data_1999_2023["Year"].drop_duplicates()
for c in MSA_codes:
    for y in years:
        county_codes = MSA_county_xwalk[MSA_county_xwalk["MSA Code"]==c]["County Code"]
        if not county_data_1999_2023.loc[(county_data_1999_2023["County Code"].isin(county_codes))&(county_data_1999_2023["Year"]==y)].empty: # if there are counties withi the MSA
            counties = county_data_1999_2023.loc[(county_data_1999_2023["County Code"].isin(county_codes))&(county_data_1999_2023["Year"]==y)] # subset the counties in the MSA
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"State"] = counties["State"].reset_index(drop=True)[0]
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"State Code"]  = counties["State Code"].reset_index(drop=True)[0]
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Population"] = np.sum(counties["Population"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Deaths"] = np.sum(counties["Deaths"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Female Deaths"] = np.sum(counties["Female Deaths"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Male Deaths"] = np.sum(counties["Male Deaths"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Firearm Deaths"] = np.sum(counties["Firearm Deaths"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Female Firearm Deaths"] = np.sum(counties["Female Firearm Deaths"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Male Firearm Deaths"] = np.sum(counties["Male Firearm Deaths"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Homicides"] = np.sum(counties["Homicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Male Homicides"] = np.sum(counties["Male Homicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Female Homicides"] = np.sum(counties["Female Homicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Firearm Homicides"] = np.sum(counties["Firearm Homicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Male Firearm Homicides"] = np.sum(counties["Male Firearm Homicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Female Firearm Homicides"] = np.sum(counties["Female Firearm Homicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Suicides"] = np.sum(counties["Suicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Male Suicides"] = np.sum(counties["Male Suicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Female Suicides"] = np.sum(counties["Female Suicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Firearm Suicides"] = np.sum(counties["Firearm Suicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Male Firearm Suicides"] = np.sum(counties["Male Firearm Suicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"Female Firearm Suicides"] = np.sum(counties["Female Firearm Suicides"].dropna().astype(int))
            MSA_data_1999_2023.loc[(MSA_data_1999_2023["MSA Code"]==c)&(MSA_data_1999_2023["Year"]==y),"COVID Deaths"] = np.sum(counties["COVID Deaths"].dropna().astype(int))

# remove rows where MSA contains population 0 or N/A
MSA_data_1999_2023 = MSA_data_1999_2023[MSA_data_1999_2023["Population"] != 0]
MSA_data_1999_2023 = MSA_data_1999_2023[MSA_data_1999_2023['Population'].notna()]

# save MSA data
MSA_data_1999_2023.to_csv("processed-data/1999-2023 MSA data.csv", index=False)
